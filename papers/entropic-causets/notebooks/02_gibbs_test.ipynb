# %% [markdown]
# # E2: Gibbs test
#
# Load `../results/e2_gibbs.csv` and inspect exact ratios.

# %%
from pathlib import Path
import pandas as pd

results = Path('../results')
print('Available:', sorted(p.name for p in results.glob('*')))
