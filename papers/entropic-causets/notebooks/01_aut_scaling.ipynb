# %% [markdown]
# # E1: |Aut| scaling
#
# Load `../results/e1_aut_scaling.csv` and inspect trends.

# %%
from pathlib import Path
import pandas as pd

results = Path('../results')
print('Available:', sorted(p.name for p in results.glob('*')))
