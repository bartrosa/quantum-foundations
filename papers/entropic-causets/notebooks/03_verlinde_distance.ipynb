# %% [markdown]
# # E3: Verlinde distance
#
# Load `../results/e3_verlinde.csv` and inspect `delta_s(r)`.

# %%
from pathlib import Path
import pandas as pd

results = Path('../results')
print('Available:', sorted(p.name for p in results.glob('*')))
